# %%
Zen of python
# Out:
#   Cell In[1], line 1
#     Zen of python
#         ^
# SyntaxError: invalid syntax

# %%
ZenOfPython
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ZenOfPython
#
# NameError: name 'ZenOfPython' is not defined

# %%
ZenOfPython
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ZenOfPython
#
# NameError: name 'ZenOfPython' is not defined

# %%
ZenOfPython
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ZenOfPython
#
# NameError: name 'ZenOfPython' is not defined
